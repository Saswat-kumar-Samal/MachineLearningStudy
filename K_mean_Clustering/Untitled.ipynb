# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('student_clustering.csv')
print('the shape of the dataframe is :- ',df.shape)
df.head(n=5)
# Out:
# the shape of the dataframe is :-  (200, 2)
#    cgpa   iq
# 0  5.13   88
# 1  5.90  113
# 2  8.36   93
# 3  8.27   97
# 4  5.45  110

# %%
plt.figure(figsize=(5,5))
plt.scatter(df.cgpa, df.iq, c = 'red')
plt.show()

# %%
# now we have calcuate the k value

from sklearn.cluster import KMeans

# %%
wcss = []
for i in range(1, 11):
    km = KMeans(n_clusters = i)
    km.fit_predict(df)
    wcss.append(km.inertia_)

print(wcss)
# Out:
# [29957.898287999997, 4184.14127, 2503.397581, 681.96966, 514.1616803171115, 398.40391184688326, 303.53129837048664, 276.89671855234724, 213.1728165651916, 188.76406670648197]

# %%
# ploting the wcss vs k graph
plt.figure(figsize=(3,3))
plt.plot(range(1,11),wcss)

# %%
X = df.values
km = KMeans(n_clusters = 4)
y_means = km.fit_predict(X)

# %%
y_means
# Out:
# array([1, 0, 2, 2, 0, 0, 2, 3, 0, 2, 1, 0, 2, 1, 0, 2, 0, 2, 0, 0, 2, 1,
#        2, 1, 1, 2, 1, 3, 2, 0, 3, 0, 3, 0, 2, 2, 3, 0, 1, 0, 1, 2, 2, 1,
#        3, 3, 2, 0, 3, 0, 1, 1, 3, 2, 3, 0, 0, 3, 0, 3, 0, 2, 2, 3, 1, 3,
#        2, 1, 0, 2, 0, 3, 2, 1, 0, 3, 0, 3, 1, 2, 2, 3, 0, 1, 3, 1, 3, 0,
#        3, 0, 3, 3, 2, 1, 2, 2, 3, 2, 1, 3, 0, 1, 1, 3, 1, 1, 2, 1, 3, 3,
#        2, 3, 0, 0, 2, 3, 2, 0, 3, 1, 1, 0, 2, 3, 2, 1, 2, 0, 1, 2, 2, 0,
#        1, 1, 0, 3, 0, 1, 2, 2, 2, 1, 0, 1, 1, 3, 1, 3, 0, 1, 3, 1, 3, 3,
#        1, 2, 0, 3, 0, 2, 1, 3, 0, 2, 3, 1, 0, 1, 1, 3, 3, 0, 3, 1, 1, 2,
#        3, 0, 1, 3, 3, 0, 0, 0, 2, 1, 2, 2, 3, 0, 2, 2, 1, 1, 2, 1, 3, 0,
#        0, 3], dtype=int32)

# %%
X[y_means == 0,1]
# Out:
# array([113., 110., 109., 110., 110., 108., 111., 111., 113., 106., 112.,
#        106., 108., 113., 108., 109., 108., 111., 109., 104., 111., 109.,
#        109., 112., 111., 109., 108., 110., 109., 111., 108., 109., 109.,
#        111., 112., 109., 111., 107., 111., 110., 108., 109., 110., 108.,
#        108., 110., 107., 111., 112., 108.])

# %%
plt.figure(figsize = (7,6))
plt.scatter(X[y_means == 0,0], X[y_means == 0,1], c = 'red')
plt.scatter(X[y_means == 1,0], X[y_means == 1,1], c = 'blue')
plt.scatter(X[y_means == 2,0], X[y_means == 2,1], c = 'green')
plt.scatter(X[y_means == 3,0], X[y_means == 3,1], c = 'yellow')
